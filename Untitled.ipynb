# %%
# Import dependicies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# %%
# Import from the main.ipynb file
df = pd.read_csv("output/offences_dates.csv", index_col=0)

# %%
# Add an additonal column to the csv that shows what season of the year the crimes have occured
# Add a function that returns the season given to a month
def get_season(month):
    if month in [12, 1, 2]:
        return 'Summer'
    elif month in [3, 4, 5]:
        return 'Autumn'
    elif month in [6, 7, 8]:
        return 'Winter'
    elif month in [9, 10, 11]:
        return 'Spring'

# Create a new column in the DataFrame with the Seasons
df['Season'] = df['Month'].apply(get_season)

# Convert the 'Reported Date' column to a datetime object
df['Reported Date'] = pd.to_datetime(df['Reported Date'])

# Create a new column for the day of the week
df['DayOfWeek'] = df['Reported Date'].dt.day_name()

# Display rows
df.head()
# Out:
#   Reported Date Suburb - Incident Postcode - Incident  \
# 0    2013-07-01          ADELAIDE                5000
# 1    2013-07-01     ALDINGA BEACH                5173
# 2    2013-07-01     ALDINGA BEACH                5173
# 3    2013-07-01      BEDFORD PARK                5042
# 4    2013-07-01            BURTON                5110
#
#    Offence Level 1 Description        Offence Level 2 Description  \
# 0  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 1  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 2  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 3  OFFENCES AGAINST THE PERSON       ROBBERY AND RELATED OFFENCES
# 4  OFFENCES AGAINST THE PERSON  OTHER OFFENCES AGAINST THE PERSON
#
#                Offence Level 3 Description  Offence count  Month  Year  \
# 0                           Common Assault              2      7  2013
# 1                           Common Assault              1      7  2013
# ...

# %%
# Calculate the number of crimes based on the Season
crimes_by_season = df.groupby('Season').size()

# Sort the total number of Crimes, by highest to lowest value
crimes_by_season = crimes_by_season.sort_values(ascending=False)

# Define the colors for the pie chart slices
colours = ['tomato', 'lightgreen', 'orange', 'lightskyblue']

# Create a pie chart that shows the number of crimes per season
crimes_by_season.plot(kind='pie', autopct='%1.1f%%', colors=colours)

# Add the title
plt.title('Violent Crimes by Seasons')

# Change labels for the legend to show crimes_by_season instead
legend_labels = [f'{season}: {format(count, ",")}' for season, count in crimes_by_season.items()]

# Add the legend
plt.legend(labels=legend_labels, title='Crimes per Season', loc='center left', bbox_to_anchor=(1, 0.5))

# Plot the pie chart
plt.show()

# %%
# Create 1 graph per season that shows how frequently different crimes were committed
# Summer 

# Filter the data for Summer
df_summer = df[df['Season'] == 'Summer']

# Calculate the number of crimes by type
crimes_by_type = df_summer.groupby('Offence Level 3 Description').size()

# Sort the data in descending order
crimes_by_type = crimes_by_type.sort_values(ascending=False)

# Create a horizontal bar chart that shows the number of crimes by type
crimes_by_type.plot(kind='barh')

# Add the axis labels and title
plt.xlabel('Number of Violent Crimes')
plt.ylabel('')
plt.title('Number of Violent Crimes by Type in Summer')

# Plot the bar graph
plt.show()

# %%
# Spring 

# Filter the data for Summer
df_summer = df[df['Season'] == 'Spring']

# Calculate the number of crimes by type
crimes_by_type = df_summer.groupby('Offence Level 3 Description').size()

# Sort the data in descending order
crimes_by_type = crimes_by_type.sort_values(ascending=False)

# Create a horizontal bar chart that shows the number of crimes by type
crimes_by_type.plot(kind='barh')

# Add the axis labels and title
plt.xlabel('Number of Violent Crimes')
plt.ylabel('')
plt.title('Number of Violent Crimes by Type in Spring')

# Plot the bar graph
plt.show()

# %%
# Autumn

# Filter the data for Summer
df_summer = df[df['Season'] == 'Autumn']

# Calculate the number of crimes by type
crimes_by_type = df_summer.groupby('Offence Level 3 Description').size()

# Sort the data in descending order
crimes_by_type = crimes_by_type.sort_values(ascending=False)

# Create a horizontal bar chart that shows the number of crimes by type
crimes_by_type.plot(kind='barh')

# Add the axis labels and title
plt.xlabel('Number of Violent Crimes')
plt.ylabel('')
plt.title('Number of Violent Crimes by Type in Autumn')

# Plot the bar graph
plt.show()

# %%
# Winter

# Filter the data for Winter
df_winter = df[df['Season'] == 'Winter']

# Calculate the number of crimes by type
crimes_by_type = df_winter.groupby('Offence Level 3 Description').size()

# Sort the data in descending order
crimes_by_type = crimes_by_type.sort_values(ascending=False)

# Create a horizontal bar chart that shows the number of crimes by type
crimes_by_type.plot(kind='barh')

# Add the axis labels and title
plt.xlabel('Number of Violent Crimes')
plt.ylabel('')
plt.title('Number of Violent Crimes by Type in Winter')

# Plot the bar graph
plt.show()
